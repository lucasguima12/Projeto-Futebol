# %%
import pandas as pd
import http.client
import json
from datetime import datetime

# %%
import http.client

conn = http.client.HTTPSConnection("api-football-v1.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "1fbf96808emshacec9ff25496937p10c070jsn2d5baedc8b83",
    'X-RapidAPI-Host': "api-football-v1.p.rapidapi.com"
}

conn.request("GET", "/v3/fixtures?league=71&season=2020", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"get":"fixtures","parameters":{"league":"71","season":"2020"},"errors":[],"results":380,"paging":{"current":1,"total":1},"response":[{"fixture":{"id":327985,"referee":"Raphael Claus, Brazil","timezone":"UTC","date":"2020-08-09T19:00:00+00:00","timestamp":1596999600,"periods":{"first":1596999600,"second":1597003200},"venue":{"id":null,"name":"Estadio do Maracan\u00e3","city":"Rio de Janeiro"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":71,"name":"Serie A","country":"Brazil","logo":"https:\/\/media-4.api-sports.io\/football\/leagues\/71.png","flag":"https:\/\/media-4.api-sports.io\/flags\/br.svg","season":2020,"round":"Regular Season - 1"},"teams":{"home":{"id":127,"name":"Flamengo","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/127.png","winner":false},"away":{"id":1062,"name":"Atletico-MG","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/1062.png","winner":true}},"goals":{"home":0,"away":1},"score":{"halftime":{"home":0,"away":1},"fulltime":{"home":0,"away":1},"extratime":{"home":null,"away":null},"penalty":{"home":null,"away":null}}},{"fixture":{"id":327986,"referee":"Savio Pereira Sampaio, Brazil","timezone":"UTC","date":"2020-10-01T00:30:00+00:00","timestamp":1601512200,"periods":{"first":1601512200,"second":1601515800},"venue":{"id":218,"name":"Est\u00e1dio Nilton Santos","city":"Rio de Janeiro"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":71,"name":"Serie A","country":"Brazil","logo":"https:\/\/media-4.api-sports.io\/football\/leagues\/71.png","flag":"https:\/\/media-4.api-sports.io\/flags\/br.svg","season":2020,"round":"Regular Season - 1"},"teams":{"home":{"id":120,"name":"Botafogo","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/120.png","winner":false},"away":{"id":118,"name":"Bahia","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/118.png","winner":true}},"goals":{"home":1,"away":2},"score":{"halftime":{"home":0,"away":1},"fulltime":{"home":1,"away":2},"extratime":{"home":null,"away":null},"penalty":{"home":null,"away":null}}},{"fixture":{"id":327987,"referee":"Anderson Daronco","timezone":"UTC","date":"2021-01-26T23:00:00+00:00","timestamp":1611702000,"periods":{"first":1611702000,"second":1611705600},"venue":{"id":258,"name":"Allianz Parque","city":"S\u00e3o Paulo, S\u00e3o Paulo"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":71,"name":"Serie A","country":"Brazil","logo":"https:\/\/media-4.api-sports.io\/football\/leagues\/71.png","flag":"https:\/\/media-4.api-sports.io\/flags\/br.svg","season":2020,"round":"Regular Season - 1"},"teams":{"home":{"id":121,"name":"Palmeiras","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/121.png","winner":null},"away":{"id":133,"name":"Vasco DA Gama","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/133.png","winner":null}},"goals":{"home":1,"away":1},"score":{"halftime":{"home":1,"away":1},"fulltime":{"home":1,"away":1},"extratime":{"home":null,"away":null},"penalty":{"home":null,"away":null}}},{"fixture":{"id":327988,"referee":"Ricardo Marques Ribeiro, Brazil","timezone":"UTC","date":"2020-08-09T19:00:00+00:00","timestamp":1596999600,"periods":{"first":1596999600,"second":1597003200},"venue":{"id":10494,"name":"Est\u00e1dio Urbano Caldeira","city":"Santos, S\u00e3o Paulo"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":71,"name":"Serie A","country":"Brazil","logo":"https:\/\/media-4.api-sports.io\/football\/leagues\/71.png","flag":"https:\/\/media-4.api-sports.io\/flags\/br.svg","season":2020,"round":"Regular Season - 1"},"teams":{"home":{"id":128,"name":"Santos","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/128.png","winner":null},"away":{"id":794,"name":"Bragantino","logo":"https:\/\/media-4.api-sports.io\/football\/teams\/794.png","winner":null}},"goals":{"home":1,"away":1},"score":{"halftime":{"home":0,"away":0},"fulltime":{"home":1,"away":1},"extratime":{"home":null,"away":null},"p ...

# %%
# Decode the byte string to a UTF-8 string
data_str = data.decode('utf-8')

# Parse the JSON data into a Python dictionary
data_dict = json.loads(data_str)

# Assuming the 'response' key contains a list of fixtures
df_times = pd.json_normalize(data_dict['response'])

# %%
df_times.loc[df_times['league.round'] == 'Regular Season - 19']
# Out:
#      fixture.id                       fixture.referee fixture.timezone  \
# 180      328165       Caio Max Augusto Vieira, Brazil              UTC
# 181      328166             Diego Pombo Lopez, Brazil              UTC
# 182      328167      Braulio Da Silva Machado, Brazil              UTC
# 183      328168           Heber Roberto Lopes, Brazil              UTC
# 184      328169    Paulo Roberto Alves Junior, Brazil              UTC
# 185      328170         Savio Pereira Sampaio, Brazil              UTC
# 186      328171  Jefferson Ferreira de Moraes, Brazil              UTC
# 187      328172             Daniel Nobre Bins, Brazil              UTC
# 188      328173                 Marielson Alves Silva              UTC
# 189      328174         Igor Junio Benevenuto, Brazil              UTC
#
#                   fixture.date  fixture.timestamp  fixture.periods.first  \
# 180  2020-11-01T19:00:00+00:00         1604257200             1604257200
# 181  2020-10-31T20:00:00+00:00         1604174400             1604174400
# 182  2020-11-02T20:00:00+00:00         1604347200             1604347200
# 183  2020-11-01T21:15:00+00:00         1604265300             1604265300
# 184  2020-10-31T22:00:00+00:00         1604181600             1604181600
# 185  2020-11-02T23:00:00+00:00         1604358000             1604358000
# 186  2020-11-01T19:00:00+00:00         1604257200             1604257200
# 187  2020-10-31T22:00:00+00:00         1604181600             1604181600
# 188  2020-11-01T00:00:00+00:00         1604188800             1604188800
# 189  2020-11-01T23:30:00+00:00         1604273400             1604273400
#
#      fixture.periods.second  fixture.venue.id  \
# 180              1604260800               NaN
# 181              1604178000             218.0
# 182              1604350800             258.0
# 183              1604268900           10494.0
# 184              1604185200               NaN
# 185              1604361600             241.0
# 186              1604260800             276.0
# 187              1604185200             230.0
# 188              1604192400             225.0
# 189              1604277000             240.0
#
#                               fixture.venue.name  \
# 180                          Estádio do Maracanã
# 181                        Estádio Nilton Santos
# 182                               Allianz Parque
# 183                      Estádio Urbano Caldeira
# 184                            Neo Química Arena
# 185                              Arena do Grêmio
# 186            Estádio Adelmar da Costa Carvalho
# 187          Estádio Major Antônio Couto Pereira
# 188  Estádio Governador Plácido Aderaldo Castelo
# 189                    Estádio de Hailé Pinheiro
#
#                   fixture.venue.city  ... goals.home goals.away  \
# 180                   Rio de Janeiro  ...          1          4
# 181                   Rio de Janeiro  ...          2          2
# 182             São Paulo, São Paulo  ...          3          0
# 183                Santos, São Paulo  ...          3          1
# 184                        Sao Paulo  ...          1          0
# 185  Porto Alegre, Rio Grande do Sul  ...          2          1
# 186               Recife, Pernambuco  ...          1          0
# 187                 Curitiba, Paraná  ...          1          0
# 188                 Fortaleza, Ceará  ...          0          1
# 189                   Goiânia, Goiás  ...          1          1
#
#      score.halftime.home  score.halftime.away score.fulltime.home  \
# 180                    1                    2                   1
# 181                    2                    1                   2
# 182                    1                    0                   3
# 183                    3                    1                   3
# 184                    1                    0                   1
# 185                    0                    0                   2
# 186                    0                    0                   1
# 187                    1                    0                   1
# 188                    0                    0                   0
# 189                    0                    1                   1
#
#     score.fulltime.away score.extratime.home score.extratime.away  \
# 180                   4                 None                 None
# 181                   2                 None                 None
# 182                   0                 None                 None
# 183                   1                 None                 None
# 184                   0                 None                 None
# 185                   1                 None                 None
# 186                   0                 None                 None
# 187                   0                 None                 None
# 188                   1                 None                 None
# 189                   1                 None                 None
#
#      score.penalty.home score.penalty.away
# 180                None               None
# 181                None               None
# 182                None               None
# 183                None               None
# 184                None               None
# 185                None               None
# 186                None               None
# 187                None               None
# 188                None               None
# 189                None               None
#
# [10 rows x 38 columns]
