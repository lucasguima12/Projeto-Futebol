# %%
import pandas as pd
import http.client
import json

# %%
conn = http.client.HTTPSConnection("v3.football.api-sports.io")

headers = {
    'x-rapidapi-host': "v3.football.api-sports.io",
    'x-rapidapi-key': "7a695a945f79581dcf932774953cbf8e"
    }

conn.request("GET", "/fixtures?league=71&season=2023", headers=headers)

res = conn.getresponse()
data = res.read()

# %%
# Decode the byte string to a UTF-8 string
data_str = data.decode('utf-8')

# Parse the JSON data into a Python dictionary
data_dict = json.loads(data_str)

# Assuming the 'response' key contains a list of fixtures
df_normalized = pd.json_normalize(data_dict['response'])

# %%
df_filtrado = df_normalized.drop(['fixture.referee', 'fixture.timezone', 'fixture.date',
       'fixture.timestamp', 'fixture.periods.first', 'fixture.periods.second',
       'fixture.venue.id', 'fixture.venue.name', 'fixture.venue.city',
       'fixture.status.long', 'fixture.status.short', 'fixture.status.elapsed','league.country', 'league.logo',
       'league.flag','teams.home.logo','teams.away.logo','score.halftime.away','score.halftime.home'], axis = 1)

# %%
df_filtrado
# Out:
#      fixture.id  league.id league.name  league.season         league.round  \
# 0       1005649         71     Serie A           2023   Regular Season - 1
# 1       1005650         71     Serie A           2023   Regular Season - 1
# 2       1005651         71     Serie A           2023   Regular Season - 1
# 3       1005652         71     Serie A           2023   Regular Season - 1
# 4       1005653         71     Serie A           2023   Regular Season - 1
# ..          ...        ...         ...            ...                  ...
# 375     1006024         71     Serie A           2023  Regular Season - 38
# 376     1006025         71     Serie A           2023  Regular Season - 38
# 377     1006026         71     Serie A           2023  Regular Season - 38
# 378     1006027         71     Serie A           2023  Regular Season - 38
# 379     1006028         71     Serie A           2023  Regular Season - 38
#
#      teams.home.id teams.home.name teams.home.winner  teams.away.id  \
# 0              127        Flamengo              True            147
# 1              120        Botafogo              True            126
# 2              121       Palmeiras              True           1193
# 3              131     Corinthians              True            135
# 4              794   RB Bragantino              True            118
# ..             ...             ...               ...            ...
# 375            135        Cruzeiro              None            121
# 376            119   Internacional              None            120
# 377            147        Coritiba              None            131
# 378            118           Bahia              None           1062
# 379           1193          Cuiaba              None            134
#
#          teams.away.name teams.away.winner  goals.home  goals.away  \
# 0               Coritiba             False         3.0         0.0
# 1              Sao Paulo             False         2.0         1.0
# 2                 Cuiaba             False         2.0         1.0
# 3               Cruzeiro             False         2.0         1.0
# 4                  Bahia             False         2.0         1.0
# ..                   ...               ...         ...         ...
# 375            Palmeiras              None         NaN         NaN
# 376             Botafogo              None         NaN         NaN
# 377          Corinthians              None         NaN         NaN
# 378          Atletico-MG              None         NaN         NaN
# 379  Atletico Paranaense              None         NaN         NaN
#
#      score.fulltime.home  score.fulltime.away score.extratime.home  \
# 0                    3.0                  0.0                 None
# 1                    2.0                  1.0                 None
# 2                    2.0                  1.0                 None
# 3                    2.0                  1.0                 None
# 4                    2.0                  1.0                 None
# ..                   ...                  ...                  ...
# 375                  NaN                  NaN                 None
# 376                  NaN                  NaN                 None
# 377                  NaN                  NaN                 None
# 378                  NaN                  NaN                 None
# 379                  NaN                  NaN                 None
#
#     score.extratime.away score.penalty.home score.penalty.away
# 0                   None               None               None
# 1                   None               None               None
# 2                   None               None               None
# 3                   None               None               None
# 4                   None               None               None
# ..                   ...                ...                ...
# 375                 None               None               None
# 376                 None               None               None
# 377                 None               None               None
# 378                 None               None               None
# 379                 None               None               None
#
# [380 rows x 19 columns]

# %%
df_filtrado_cor = df_filtrado.loc[(df_filtrado['teams.home.id'] == 131) | (df_filtrado['teams.away.id'] == 131)].reset_index()

# %%
df_filtrado_cor.drop('index', axis = 1, inplace = True)

# %%
df_filtrado_cor
# Out:
#     fixture.id  league.id league.name  league.season         league.round  \
# 0      1005652         71     Serie A           2023   Regular Season - 1
# 1      1005663         71     Serie A           2023   Regular Season - 2
# 2      1005671         71     Serie A           2023   Regular Season - 3
# 3      1005682         71     Serie A           2023   Regular Season - 4
# 4      1005690         71     Serie A           2023   Regular Season - 5
# 5      1005702         71     Serie A           2023   Regular Season - 6
# 6      1005709         71     Serie A           2023   Regular Season - 7
# 7      1005722         71     Serie A           2023   Regular Season - 8
# 8      1005738         71     Serie A           2023   Regular Season - 9
# 9      1005742         71     Serie A           2023  Regular Season - 10
# 10     1005752         71     Serie A           2023  Regular Season - 11
# 11     1005766         71     Serie A           2023  Regular Season - 12
# 12     1005772         71     Serie A           2023  Regular Season - 13
# 13     1005784         71     Serie A           2023  Regular Season - 14
# 14     1005792         71     Serie A           2023  Regular Season - 15
# 15     1005807         71     Serie A           2023  Regular Season - 16
# 16     1005812         71     Serie A           2023  Regular Season - 17
# 17     1005825         71     Serie A           2023  Regular Season - 18
# 18     1005832         71     Serie A           2023  Regular Season - 19
# 19     1005844         71     Serie A           2023  Regular Season - 20
# 20     1005852         71     Serie A           2023  Regular Season - 21
# 21     1005862         71     Serie A           2023  Regular Season - 22
# 22     1005877         71     Serie A           2023  Regular Season - 23
# 23     1005882         71     Serie A           2023  Regular Season - 24
# 24     1005891         71     Serie A           2023  Regular Season - 25
# 25     1005902         71     Serie A           2023  Regular Season - 26
# 26     1005909         71     Serie A           2023  Regular Season - 27
# 27     1005922         71     Serie A           2023  Regular Season - 28
# 28     1005938         71     Serie A           2023  Regular Season - 29
# 29     1005942         71     Serie A           2023  Regular Season - 30
# 30     1005952         71     Serie A           2023  Regular Season - 31
# 31     1005963         71     Serie A           2023  Regular Season - 32
# 32     1005972         71     Serie A           2023  Regular Season - 33
# 33     1005985         71     Serie A           2023  Regular Season - 34
# 34     1005992         71     Serie A           2023  Regular Season - 35
# 35     1006000         71     Serie A           2023  Regular Season - 36
# 36     1006012         71     Serie A           2023  Regular Season - 37
# 37     1006026         71     Serie A           2023  Regular Season - 38
#
#     teams.home.id      teams.home.name teams.home.winner  teams.away.id  \
# 0             131          Corinthians              True            135
# 1             151                Goias              True            131
# 2             121            Palmeiras              True            131
# 3             131          Corinthians              None            154
# 4             120             Botafogo              True            131
# 5             131          Corinthians              None            126
# 6             127             Flamengo              True            131
# 7             131          Corinthians              True            124
# 8             125      America Mineiro              True            131
# 9             131          Corinthians              None           1193
# 10            128               Santos             False            131
# 11            134  Atletico Paranaense              True            131
# 12            131          Corinthians             False            794
# 13           1062          Atletico-MG             False            131
# 14            131          Corinthians              None            130
# 15            118                Bahia              None            131
# 16            131          Corinthians              True            133
# 17            119        Internacional              None            131
# 18            131          Corinthians              True            147
# 19            135             Cruzeiro              None            131
# 20            131          Corinthians              None            151
# 21            131          Corinthians              None            121
# 22            154         Fortaleza EC              True            131
# 23            131          Corinthians              True            120
# 24            126            Sao Paulo              True            131
# 25            131          Corinthians              None            127
# 26            124           Fluminense              None            131
# 27            131          Corinthians              None            125
# 28           1193               Cuiaba             False            131
# 29            131          Corinthians              None            128
# 30            131          Corinthians              True            134
# 31            794        RB Bragantino              True            131
# 32            131          Corinthians              None           1062
# 33            130               Gremio              None            131
# 34            131          Corinthians              None            118
# 35            133        Vasco DA Gama              None            131
# 36            131          Corinthians              None            119
# 37            147             Coritiba              None            131
#
#         teams.away.name teams.away.winner  goals.home  goals.away  \
# 0              Cruzeiro             False         2.0         1.0
# 1           Corinthians             False         3.0         1.0
# 2           Corinthians             False         2.0         1.0
# 3          Fortaleza EC              None         1.0         1.0
# 4           Corinthians             False         3.0         0.0
# 5             Sao Paulo              None         1.0         1.0
# 6           Corinthians             False         1.0         0.0
# 7            Fluminense             False         2.0         0.0
# 8           Corinthians             False         2.0         0.0
# 9                Cuiaba              None         1.0         1.0
# 10          Corinthians              True         0.0         2.0
# 11          Corinthians             False         1.0         0.0
# 12        RB Bragantino              True         0.0         1.0
# 13          Corinthians              True         0.0         1.0
# 14               Gremio              None         4.0         4.0
# 15          Corinthians              None         0.0         0.0
# 16        Vasco DA Gama             False         3.0         1.0
# 17          Corinthians              None         2.0         2.0
# 18             Coritiba             False         3.0         1.0
# 19          Corinthians              None         1.0         1.0
# 20                Goias              None         1.0         1.0
# 21            Palmeiras              None         0.0         0.0
# 22          Corinthians             False         2.0         1.0
# 23             Botafogo             False         1.0         0.0
# 24          Corinthians             False         2.0         1.0
# 25             Flamengo              None         1.0         1.0
# 26          Corinthians              None         3.0         3.0
# 27      America Mineiro              None         1.0         1.0
# 28          Corinthians              True         0.0         1.0
# 29               Santos              None         1.0         1.0
# 30  Atletico Paranaense             False         1.0         0.0
# 31          Corinthians             False         1.0         0.0
# 32          Atletico-MG              None         1.0         1.0
# 33          Corinthians              None         NaN         NaN
# 34                Bahia              None         NaN         NaN
# 35          Corinthians              None         NaN         NaN
# 36        Internacional              None         NaN         NaN
# 37          Corinthians              None         NaN         NaN
#
#     score.fulltime.home  score.fulltime.away score.extratime.home  \
# 0                   2.0                  1.0                 None
# 1                   3.0                  1.0                 None
# 2                   2.0                  1.0                 None
# 3                   1.0                  1.0                 None
# 4                   3.0                  0.0                 None
# 5                   1.0                  1.0                 None
# 6                   1.0                  0.0                 None
# 7                   2.0                  0.0                 None
# 8                   2.0                  0.0                 None
# 9                   1.0                  1.0                 None
# 10                  0.0                  2.0                 None
# 11                  1.0                  0.0                 None
# 12                  0.0                  1.0                 None
# 13                  0.0                  1.0                 None
# 14                  4.0                  4.0                 None
# 15                  0.0                  0.0                 None
# 16                  3.0                  1.0                 None
# 17                  2.0                  2.0                 None
# 18                  3.0                  1.0                 None
# 19                  1.0                  1.0                 None
# 20                  1.0                  1.0                 None
# 21                  0.0                  0.0                 None
# 22                  2.0                  1.0                 None
# 23                  1.0                  0.0                 None
# 24                  2.0                  1.0                 None
# 25                  1.0                  1.0                 None
# 26                  3.0                  3.0                 None
# 27                  1.0                  1.0                 None
# 28                  0.0                  1.0                 None
# 29                  1.0                  1.0                 None
# 30                  1.0                  0.0                 None
# 31                  1.0                  0.0                 None
# 32                  1.0                  1.0                 None
# 33                  NaN                  NaN                 None
# 34                  NaN                  NaN                 None
# 35                  NaN                  NaN                 None
# 36                  NaN                  NaN                 None
# 37                  NaN                  NaN                 None
#
#    score.extratime.away score.penalty.home score.penalty.away
# 0                  None               None               None
# 1                  None               None               None
# 2                  None               None               None
# 3                  None               None               None
# 4                  None               None               None
# 5                  None               None               None
# 6                  None               None               None
# 7                  None               None               None
# 8                  None               None               None
# 9                  None               None               None
# 10                 None               None               None
# 11                 None               None               None
# 12                 None               None               None
# 13                 None               None               None
# 14                 None               None               None
# 15                 None               None               None
# 16                 None               None               None
# 17                 None               None               None
# 18                 None               None               None
# 19                 None               None               None
# 20                 None               None               None
# 21                 None               None               None
# 22                 None               None               None
# 23                 None               None               None
# 24                 None               None               None
# 25                 None               None               None
# 26                 None               None               None
# 27                 None               None               None
# 28                 None               None               None
# 29                 None               None               None
# 30                 None               None               None
# 31                 None               None               None
# 32                 None               None               None
# 33                 None               None               None
# 34                 None               None               None
# 35                 None               None               None
# 36                 None               None               None
# 37                 None               None               None

# %%
dataframes_list = []

for fixture in df_filtrado_cor['fixture.id']:
    conn = http.client.HTTPSConnection("v3.football.api-sports.io")
    headers = {
        'x-rapidapi-host': "v3.football.api-sports.io",
        'x-rapidapi-key': "7a695a945f79581dcf932774953cbf8e"
        }

    conn.request("GET", f"/fixtures/players?fixture={fixture}&team=131", headers=headers)

    res = conn.getresponse()
    data = res.read()
    players_data = json.loads(data.decode("utf-8"))
    # Check if the 'response' key is in the dictionary
    if 'response' in players_data:
        # Normalize the 'response' data and append the DataFrame to the list
        df_players = pd.json_normalize(players_data['response'])
        dataframes_list.append(df_players)

# Concatenate all the DataFrames into one
df_jogadores = pd.concat(dataframes_list, ignore_index=True)

# %%
df_jogadores
# Out:
#                                              players  team.id    team.name  \
# 0  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 1  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 2  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 3  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 4  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 5  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 6  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 7  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 8  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
# 9  [{'player': {'id': 10229, 'name': 'Cássio', 'p...      131  Corinthians
#
#                                            team.logo  \
# 0  https://media-4.api-sports.io/football/teams/1...
# 1  https://media-4.api-sports.io/football/teams/1...
# 2  https://media-4.api-sports.io/football/teams/1...
# 3  https://media-4.api-sports.io/football/teams/1...
# 4  https://media-4.api-sports.io/football/teams/1...
# 5  https://media-4.api-sports.io/football/teams/1...
# 6  https://media-4.api-sports.io/football/teams/1...
# 7  https://media-4.api-sports.io/football/teams/1...
# 8  https://media-4.api-sports.io/football/teams/1...
# 9  https://media-4.api-sports.io/football/teams/1...
#
#                  team.update
# 0  2023-11-10T04:08:14+00:00
# 1  2023-11-10T04:08:26+00:00
# 2  2023-11-10T04:08:35+00:00
# 3  2023-11-10T04:08:53+00:00
# 4  2023-11-10T04:09:11+00:00
# 5  2023-11-10T04:09:21+00:00
# 6  2023-11-10T04:09:33+00:00
# 7  2023-11-10T04:09:48+00:00
# 8  2023-11-10T04:10:33+00:00
# 9  2023-11-10T04:10:50+00:00

# %%
# Initialize an empty list to store DataFrames for each player's statistics
dataframes_list = []

# Loop over each row in the DataFrame
for index, row in df_jogadores.iterrows():
    # 'players' is a list of dictionaries, so we iterate over it
    for player_info in row['players']:
        # Normalize the 'statistics' data for the current player
        # Assuming 'statistics' is a key in the player_info dictionary and it's not None
        if 'statistics' in player_info and player_info['statistics'] is not None:
            statistics_df = pd.json_normalize(player_info['statistics'])
            # Add the player ID, player name, team name, and team ID
            statistics_df['player_id'] = player_info['player']['id']
            statistics_df['player_name'] = player_info['player']['name']
            # Here we extract team name and team ID from the row in df_filtrado
            statistics_df['team_name'] = row['team.name']  # Replace with the actual column name for team name in df_filtrado
            statistics_df['team_id'] = row['team.id']  # Replace with the actual column name for team ID in df_filtrado
            # Append the flattened DataFrame to the list
            dataframes_list.append(statistics_df)

# Concatenate all the DataFrames in the list into one final DataFrame
df_all_players_statistics = pd.concat(dataframes_list, ignore_index=True)

# Specify the column order to ensure the desired columns are first
column_order = ['player_id', 'player_name', 'team_name', 'team_id'] + [col for col in df_all_players_statistics.columns if col not in ['player_id', 'player_name', 'team_name', 'team_id']]
df_all_players_statistics = df_all_players_statistics[column_order]

# %%
df_all_players_statistics
# Out:
#      player_id         player_name    team_name  team_id offsides  \
# 0        10229              Cássio  Corinthians      131     None
# 1         2411              Fagner  Corinthians      131     None
# 2        10233        Bruno Méndez  Corinthians      131     None
# 3        12744                 Gil  Corinthians      131     None
# 4         9742        Matheus Bidú  Corinthians      131     None
# ..         ...                 ...          ...      ...      ...
# 225       9876        Fábio Santos  Corinthians      131     None
# 226     267770                Roni  Corinthians      131     None
# 227     237706  Chrystian Barletta  Corinthians      131     None
# 228     312615             Giovane  Corinthians      131     None
# 229     306854      Felipe Augusto  Corinthians      131     None
#
#     games.minutes  games.number games.position games.rating  games.captain  \
# 0              99            12              G          6.3           True
# 1              99            23              D          7.3          False
# 2              99            25              D          6.3          False
# 3              99             4              D          7.2          False
# 4              94            21              D          7.3          False
# ..            ...           ...            ...          ...            ...
# 225          None             6              D         None          False
# 226          None            29              M         None          False
# 227          None            77              F         None          False
# 228          None            17              F         None          False
# 229          None            41              F         None          False
#
#      ...  dribbles.past fouls.drawn fouls.committed cards.yellow  cards.red  \
# 0    ...           None           1            None            0          0
# 1    ...              1        None               1            1          0
# 2    ...           None        None               2            0          0
# 3    ...           None        None            None            0          0
# 4    ...           None           4               1            0          0
# ..   ...            ...         ...             ...          ...        ...
# 225  ...           None        None            None            0          0
# 226  ...           None        None            None            0          0
# 227  ...           None        None            None            0          0
# 228  ...           None        None            None            0          0
# 229  ...           None        None            None            0          0
#
#     penalty.won penalty.commited penalty.scored penalty.missed penalty.saved
# 0          None             None              0              0             0
# 1          None             None              0              0          None
# 2          None             None              0              0          None
# 3          None             None              0              0          None
# 4          None             None              0              0          None
# ..          ...              ...            ...            ...           ...
# 225        None             None              0              0          None
# 226        None             None              0              0          None
# 227        None             None              0              0          None
# 228        None             None              0              0          None
# 229        None             None              0              0          None
#
# [230 rows x 37 columns]
